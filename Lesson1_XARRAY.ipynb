# %%
import numpy as np

# %%
import xarray as xr

# %%
ds = xr.open_dataset('/glade/collections/rda/data/ds633.0/e5.oper.an.sfc/202101/e5.oper.an.sfc.128_167_2t.ll025sc.2021010100_2021013123.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (latitude: 721, longitude: 1440, time: 744)
# Coordinates:
#   * latitude   (latitude) float64 90.0 89.75 89.5 89.25 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float64 0.0 0.25 0.5 0.75 ... 359.0 359.2 359.5 359.8
#   * time       (time) datetime64[ns] 2021-01-01 ... 2021-01-31T23:00:00
# Data variables:
#     VAR_2T     (time, latitude, longitude) float32 ...
#     utc_date   (time) int32 ...
# Attributes:
#     DATA_SOURCE:          ECMWF: https://cds.climate.copernicus.eu, Copernicu...
#     NETCDF_CONVERSION:    CISL RDA: Conversion from ECMWF GRIB1 data to netCDF4.
#     NETCDF_VERSION:       4.7.4
#     CONVERSION_PLATFORM:  Linux r1i4n6 4.12.14-95.51-default #1 SMP Fri Apr 1...
#     CONVERSION_DATE:      Fri Apr  2 17:08:42 MDT 2021
#     Conventions:          CF-1.6
#     NETCDF_COMPRESSION:   NCO: Precision-preserving compression to netCDF4/HD...
#     history:              Fri Apr  2 17:08:59 2021: ncks -4 --ppc default=7 e...
# ...

# %%
ds ['VAR_2T'].isel(time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7aeeaad01f10> in <module>
# ----> 1 ds ['VAR_2T'].isel(time)
#
# NameError: name 'time' is not defined
